# %%
import networkx as nx
import networkx.algorithms.bipartite as bi

# %%
g = net.davis_southern_women_graph()

# %%
women = g.graph['top']
events = g.graph['bottom']

W = bi.projected_graph(g, women)

# project bipartite graph onto women nodes keeping number of co-occurence
# the degree computed is weighted and counts the total number of shared contacts
W = bi.weighted_projected_graph(g, women, ratio=False)

# %%
weights = [edata['weight'] for f,t,edata in W.edges(data=True)]
plt.figure(figsize = (10,10))
nx.draw_networkx(W, width=weights, edge_color=weights)

# %%
women
# Out:
# ['Evelyn Jefferson',
#  'Laura Mandeville',
#  'Theresa Anderson',
#  'Brenda Rogers',
#  'Charlotte McDowd',
#  'Frances Anderson',
#  'Eleanor Nye',
#  'Pearl Oglethorpe',
#  'Ruth DeSand',
#  'Verne Sanderson',
#  'Myra Liddel',
#  'Katherina Rogers',
#  'Sylvia Avondale',
#  'Nora Fayette',
#  'Helen Lloyd',
#  'Dorothy Murchison',
#  'Olivia Carleton',
#  'Flora Price']

# %%
events
# Out:
# ['E1',
#  'E2',
#  'E3',
#  'E4',
#  'E5',
#  'E6',
#  'E7',
#  'E8',
#  'E9',
#  'E10',
#  'E11',
#  'E12',
#  'E13',
#  'E14']

# %%
g2 = nx.davis_southern_women_graph()
women = g2.graph['bottom']
events = g2.graph['top']

# project bipartite graph onto women nodes
e = bi.projected_graph(g2, women)

# project bipartite graph onto women nodes keeping number of co-occurence
# the degree computed is weighted and counts the total number of shared contacts
e = bi.weighted_projected_graph(g2, women, ratio=False)

# %%
e.edges(data=True)
weights=[edata['weight'] for f,t,edata in e.edges(data=True)]
plt.figure(figsize=(10,10))
nx.draw_networkx(e, width=weights, edge_color=weights)

# %% [markdown]
# From the two graphs, we understand and see that a groups of women attended almost all of the same events and other not.
